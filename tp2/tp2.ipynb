# %%
import pandas as pd
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

df = pd.read_csv('AmericaNorte.csv')

print(df.to_string())
# Out:
#             ttl     rttMean     rttPrev   latitud   longitud
# 0   172.17.80.1  120.740779    0.000000   noLocAv   noLocAvc
# 1     10.90.0.1  502.123767  381.382988   noLocAv   noLocAvc
# 2  10.171.0.145  586.799431   84.675664   noLocAv   noLocAvc
# 3       3.3.3.1  686.660106   99.860675   47.6339  -122.3476
# 4  200.0.17.225  731.175431   44.515325  -34.6131   -58.3772

# %%
df = df[df.latitud != "noLocAv"]
geometry = gpd.points_from_xy(df.longitud, df.latitud)

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

gdf = gpd.GeoDataFrame(geometry=geometry)

ax = world.plot(
    color='white', edgecolor='black')

gdf.plot(ax=ax, color='red')
# Out:
# /tmp/ipykernel_17733/3557432665.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <AxesSubplot:>

# %%
cities = gpd.read_file('Africa.csv')
#base = world.plot(color='white', edgecolor='black')
cities
#cities.plot(ax=base, marker='o', color='red', markersize=5)
# Out:
#               ttl             rttMean              rttPrev  latitud  \
# 0     172.17.80.1  123.94737402598064                  0.0  noLocAv
# 1       10.90.0.1  130.24808565775552    6.300711631774888  noLocAv
# 2         3.3.3.1  130.41384518146515  0.16575952370962455  47.6339
# 3   213.248.84.80   269.0695921579997   138.65574697653454  25.7743
# 4  62.115.119.230   272.0609995035025   2.9914073455028074  39.0437
# 5  62.115.122.158   344.2820585691012     72.2210590655987  48.8534
# 6    62.115.42.51   350.5490566122121   6.2669980431109025  48.8534
#
#     longitud geometry
# 0   noLocAvc     None
# 1   noLocAvc     None
# 2  -122.3476     None
# 3   -80.1937     None
# 4   -77.4875     None
# 5     2.3488     None
# 6     2.3488     None
